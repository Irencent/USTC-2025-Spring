# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
BASE_URL = "https://ysjt.ustc.edu.cn"
START_PAGE = 1
MAX_PAGE = 393  # 当前最大页数（可自动探测也可以写死）
OUTPUT_FILE = "vegetable_price_links.txt"

headers = {
    "User-Agent": "Mozilla/5.0"
}

def fetch_page(page_num):
    if page_num == 1:
        url = f"{BASE_URL}/wjxx/list.htm"
    else:
        url = f"{BASE_URL}/wjxx/list{page_num}.htm"
    print(f"Fetching: {url}")
    res = requests.get(url, headers=headers, timeout=10)
    res.encoding = res.apparent_encoding
    return res.text

def parse_page(html):
    soup = BeautifulSoup(html, 'html.parser')
    items = []
    for li in soup.find_all("li", class_="cle"):
        title_tag = li.find("a")
        date_tag = li.find("div", class_="time fr")
        if title_tag and date_tag:
            title = title_tag.get_text(strip=True)
            if "蔬菜价格信息" in title:
                relative_link = title_tag['href']
                full_link = BASE_URL + relative_link
                date = date_tag.get_text(strip=True)
                items.append((title, date, full_link))
    return items

def crawl_all_pages():
    all_items = []
    for page_num in range(1, MAX_PAGE + 1):
        try:
            html = fetch_page(page_num)
            items = parse_page(html)
            all_items.extend(items)
            time.sleep(0.5)  # 友好间隔
        except Exception as e:
            print(f"Error on page {page_num}: {e}")
            continue
    return all_items

def save_to_file(items, filename):
    with open(filename, "w", encoding="utf-8") as f:
        for title, date, link in items:
            f.write(f"{title} | {date} | {link}\n")
    print(f"Saved {len(items)} items to {filename}")

# %%
all_items = crawl_all_pages()
save_to_file(all_items, OUTPUT_FILE)
# Out:
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list2.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list3.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list4.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list5.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list6.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list7.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list8.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list9.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list10.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list11.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list12.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list13.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list14.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list15.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list16.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list17.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list18.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list19.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list20.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list21.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list22.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list23.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list24.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list25.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list26.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list27.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list28.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list29.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list30.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list31.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list32.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list33.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list34.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list35.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list36.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list37.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list38.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list39.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list40.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list41.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list42.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list43.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list44.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list45.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list46.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list47.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list48.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list49.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list50.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list51.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list52.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list53.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list54.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list55.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list56.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list57.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list58.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list59.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list60.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list61.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list62.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list63.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list64.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list65.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list66.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list67.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list68.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list69.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list70.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list71.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list72.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list73.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list74.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list75.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list76.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list77.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list78.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list79.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list80.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list81.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list82.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list83.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list84.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list85.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list86.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list87.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list88.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list89.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list90.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list91.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list92.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list93.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list94.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list95.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list96.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list97.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list98.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list99.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list100.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list101.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list102.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list103.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list104.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list105.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list106.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list107.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list108.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list109.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list110.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list111.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list112.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list113.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list114.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list115.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list116.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list117.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list118.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list119.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list120.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list121.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list122.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list123.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list124.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list125.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list126.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list127.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list128.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list129.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list130.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list131.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list132.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list133.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list134.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list135.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list136.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list137.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list138.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list139.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list140.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list141.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list142.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list143.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list144.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list145.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list146.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list147.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list148.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list149.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list150.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list151.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list152.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list153.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list154.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list155.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list156.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list157.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list158.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list159.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list160.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list161.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list162.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list163.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list164.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list165.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list166.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list167.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list168.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list169.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list170.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list171.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list172.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list173.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list174.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list175.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list176.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list177.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list178.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list179.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list180.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list181.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list182.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list183.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list184.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list185.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list186.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list187.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list188.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list189.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list190.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list191.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list192.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list193.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list194.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list195.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list196.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list197.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list198.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list199.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list200.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list201.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list202.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list203.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list204.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list205.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list206.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list207.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list208.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list209.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list210.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list211.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list212.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list213.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list214.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list215.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list216.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list217.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list218.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list219.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list220.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list221.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list222.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list223.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list224.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list225.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list226.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list227.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list228.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list229.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list230.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list231.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list232.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list233.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list234.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list235.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list236.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list237.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list238.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list239.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list240.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list241.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list242.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list243.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list244.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list245.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list246.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list247.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list248.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list249.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list250.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list251.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list252.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list253.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list254.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list255.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list256.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list257.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list258.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list259.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list260.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list261.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list262.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list263.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list264.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list265.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list266.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list267.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list268.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list269.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list270.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list271.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list272.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list273.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list274.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list275.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list276.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list277.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list278.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list279.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list280.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list281.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list282.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list283.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list284.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list285.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list286.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list287.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list288.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list289.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list290.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list291.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list292.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list293.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list294.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list295.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list296.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list297.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list298.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list299.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list300.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list301.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list302.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list303.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list304.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list305.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list306.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list307.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list308.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list309.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list310.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list311.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list312.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list313.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list314.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list315.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list316.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list317.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list318.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list319.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list320.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list321.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list322.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list323.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list324.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list325.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list326.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list327.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list328.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list329.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list330.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list331.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list332.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list333.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list334.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list335.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list336.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list337.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list338.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list339.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list340.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list341.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list342.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list343.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list344.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list345.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list346.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list347.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list348.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list349.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list350.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list351.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list352.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list353.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list354.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list355.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list356.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list357.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list358.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list359.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list360.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list361.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list362.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list363.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list364.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list365.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list366.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list367.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list368.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list369.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list370.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list371.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list372.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list373.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list374.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list375.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list376.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list377.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list378.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list379.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list380.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list381.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list382.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list383.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list384.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list385.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list386.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list387.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list388.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list389.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list390.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list391.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list392.htm
# Fetching: https://ysjt.ustc.edu.cn/wjxx/list393.htm
# Saved 4866 items to vegetable_price_links.txt

# %%
import requests
import re
import json
from bs4 import BeautifulSoup
from tqdm import tqdm

def load_links(txt_path, max_count=None):
    links = []
    with open(txt_path, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split('|')
            if len(parts) == 3:
                title = parts[0].strip()
                url = parts[2].strip()
                match = re.search(r'第(\d+)期', title)
                if match:
                    period = match.group(1)
                    links.append((period, url))
    # 按照期号降序排序，默认从最新的爬
    links.sort(key=lambda x: int(x[0]), reverse=True)
    return links[:max_count] if max_count else links

def extract_date_and_prices_from_page(html):
    soup = BeautifulSoup(html, 'html.parser')

    # 直接提取整页文本
    content = soup.get_text(separator='', strip=True)

    # 提取日期（格式：XXXX年X月X日）
    date_match = re.search(r'(\d{4}年\d{1,2}月\d{1,2}日)', content)
    date_str = date_match.group(1) if date_match else None

    # 清洗后提取价格信息
    content_cleaned = re.sub(r'蔬菜价格信息（第\d+期）\s*' + (date_str or ''), '', content)
    content_cleaned = re.sub(r'价格单位[：:]\s*元/斤', '', content_cleaned)
    content_cleaned = re.sub(r'(名称)?单价', '', content_cleaned)

    pattern = re.findall(r'([\u4e00-\u9fa5A-Za-z（）()]{1,10}?)(\d+(?:\.\d+)?)', content_cleaned)

    price_dict = {}
    for name, price in pattern:
        name = name.strip()
        if name and len(name) <= 7:
            try:
                price_dict[name] = float(price)
            except:
                continue

    return date_str, price_dict


def crawl_from_file(txt_path, max_count=None):
    links = load_links(txt_path, max_count)
    all_data = {}
    for period, url in tqdm(links, desc="📦 正在爬取"):
        try:
            resp = requests.get(url, timeout=10)
            resp.encoding = 'utf-8'
            prices = extract_date_and_prices_from_page(resp.text)
            all_data[period] = prices
        except Exception as e:
            print(f"⚠️ 错误: 第{period}期 - {e}")
    return all_data

# ✨ 运行示例
if __name__ == "__main__":
    max_issues = None  # ✅ 修改这里控制期数，比如 10, 50, None（全部）
    result = crawl_from_file("vegetable_price_links.txt", max_count=max_issues)
    with open("vegetable_prices.json", "w", encoding="utf-8") as f:
        json.dump(result, f, ensure_ascii=False, indent=2)
    print(f"✅ 共保存 {len(result)} 期数据至 vegetable_prices.json")
# Out:
# 📦 正在爬取:   0%|          | 0/4725 [00:00<?, ?it/s]
# 📦 正在爬取:  16%|█▌        | 744/4725 [01:46<41:07,  1.61it/s]
# ⚠️ 错误: 第6326期 - HTTPSConnectionPool(host='ysjt.ustc.edu.cn', port=443): Max retries exceeded with url: /2023/0222/c18038a592842/page.htm (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)')))
# 📦 正在爬取:  20%|██        | 961/4725 [02:31<1:21:05,  1.29s/it]
# ⚠️ 错误: 第6086期 - HTTPSConnectionPool(host='ysjt.ustc.edu.cn', port=443): Read timed out. (read timeout=10)
# 📦 正在爬取:  35%|███▍      | 1643/4725 [03:46<31:21,  1.64it/s]
# ⚠️ 错误: 第5296期 - HTTPSConnectionPool(host='ysjt.ustc.edu.cn', port=443): Max retries exceeded with url: /2020/0110/c18038a411560/page.htm (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)')))
# 📦 正在爬取:  45%|████▌     | 2146/4725 [05:01<04:36,  9.34it/s]
# ⚠️ 错误: 第4666期 - HTTPSConnectionPool(host='ysjt.ustc.edu.cn', port=443): Max retries exceeded with url: /2018/0531/c18038a383510/page.htm (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)')))
# 📦 正在爬取: 100%|██████████| 4725/4725 [10:20<00:00,  7.62it/s]
# ✅ 共保存 4629 期数据至 vegetable_prices.json

# %%
import json
import pandas as pd

# 读取 JSON 文件
with open('vegetable_prices.json', 'r', encoding='utf-8') as file:
    vegetable_data = json.load(file)

# 用来存储整理后的数据
data = []

# 遍历每一期的蔬菜价格数据
for period, details in vegetable_data.items():
    date = details[0]  # 日期是列表的第一个元素
    prices = details[1]  # 蔬菜价格信息是列表的第二个元素
    
    for vegetable, price in prices.items():
        # 将数据添加到列表中
        data.append({
            'period': period,
            'vegetable': vegetable,
            'price': price,
            'date': date  # 添加日期信息
        })

# 将整理后的数据转换为 DataFrame
df = pd.DataFrame(data)

# 显示前几行数据以验证结果
print(df.head())

# 将整理后的数据保存为 CSV 文件
df.to_csv('vegetable_prices.csv', index=False)
# Out:
#   period vegetable  price        date
# 0   7149        韭菜    1.8  2025年3月31日
# 1   7149       四月蔓    1.0  2025年3月31日
# 2   7149        瓠子    2.3  2025年3月31日
# 3   7149      铁棍山药    3.5  2025年3月31日
# 4   7149       水芹菜    3.5  2025年3月31日
